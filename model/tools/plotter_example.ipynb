# %%
import plotter
import matplotlib.pyplot as plt
models = plotter.model_info(verbose=False)[::-1][6:12]
# models.remove(models[-2])
models

# %%
cusplotter = plotter.HDF5Plotter(file_pattern=f"{models[6]}/rkiter-*.hdf5")
fig, ax = plt.subplots()
plot_params = {'y': True, 'yscale':'log', 'xlim':(0.01,0.1), 'ylim':(1e-9,1e4)}
params1 = {**plot_params, **{'label':f"fast rot, weak B",'linestyle':'-'}}
ax=cusplotter.plotevolveline('face', method='bratio', plot_params=params1, ax=ax)

# %%
model0plotter = plotter.HDF5Plotter(file_pattern=f"{models[0]}/rkiter-*.hdf5",exclude_last_n_files=1)
model1plotter = plotter.HDF5Plotter(file_pattern=f"{models[1]}/rkiter-*.hdf5",exclude_last_n_files=1)
model2plotter = plotter.HDF5Plotter(file_pattern=f"{models[2]}/rkiter-*.hdf5",exclude_last_n_files=1)
model3plotter = plotter.HDF5Plotter(file_pattern=f"{models[3]}/rkiter-*.hdf5",exclude_last_n_files=1)
model4plotter = plotter.HDF5Plotter(file_pattern=f"{models[4]}/rkiter-*.hdf5",exclude_last_n_files=1)
model5plotter = plotter.HDF5Plotter(file_pattern=f"{models[5]}/rkiter-*.hdf5",exclude_last_n_files=1)

# %%
plot_params = {'xcale':'log'}
ax= model0plotter.plot_map('face', method='bnorm', plot_params={**plot_params})
# ax.set_xscale('log')
# model0plotter.plot_map('face', method='bpol', plot_params={**plot_params})
ax=model0plotter.plot_map('face', method='btor', plot_params={**plot_params})
ax.set_xscale('log')

# %%
from matplotlib import lines as mlines
fig, ax2 = plt.subplots()
plot_params = {'y': True, 'ylabel':r'$E_{Mag} (erg)$','yscale':'log','title':'Magnetic energy','legend':False}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax2=model0plotter.plotevolveline('face', method='btorenergy', plot_params=params0, ax=ax2)
ax2=model1plotter.plotevolveline('face', method='btorenergy', plot_params=params1, ax=ax2)
ax2=model2plotter.plotevolveline('face', method='btorenergy', plot_params=params2, ax=ax2)
ax2=model3plotter.plotevolveline('face', method='btorenergy', plot_params=params3, ax=ax2)
ax2=model4plotter.plotevolveline('face', method='btorenergy', plot_params=params4, ax=ax2)
ax2=model5plotter.plotevolveline('face', method='btorenergy', plot_params=params5, ax=ax2)

params0 = {**plot_params, **{'linestyle':':', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':':', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':':', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':':', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':':', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':':', 'color':'purple'}}
ax2=model0plotter.plotevolveline('face', method='bpolenergy', plot_params=params0, ax=ax2)
ax2=model1plotter.plotevolveline('face', method='bpolenergy', plot_params=params1, ax=ax2)
ax2=model2plotter.plotevolveline('face', method='bpolenergy', plot_params=params2, ax=ax2)
ax2=model3plotter.plotevolveline('face', method='bpolenergy', plot_params=params3, ax=ax2)
ax2=model4plotter.plotevolveline('face', method='bpolenergy', plot_params=params4, ax=ax2)
ax2=model5plotter.plotevolveline('face', method='bpolenergy', plot_params=params5, ax=ax2)

# Create custom legend handles
toroidal_line = mlines.Line2D([], [], color='black', linestyle='-.', label='Toroidal')
poloidal_line = mlines.Line2D([], [], color='black', linestyle=':', label='Poloidal')
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax2.add_artist(ax2.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))
ax2.add_artist(ax2.legend(handles=[toroidal_line, poloidal_line], loc='upper right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':'ratio','yscale':'log','title':r'$E_{tor}/E_{pol}$','legend':False}
params0 = {**plot_params, **{'linestyle':':', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':':', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':':', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':':', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':':', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':':', 'color':'purple'}}
ax3=model0plotter.plotevolveline('face', method='bratio', plot_params=params0, ax=ax3)
ax3=model1plotter.plotevolveline('face', method='bratio', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='bratio', plot_params=params2, ax=ax3)
ax3=model3plotter.plotevolveline('face', method='bratio', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='bratio', plot_params=params4, ax=ax3)
ax3=model5plotter.plotevolveline('face', method='bratio', plot_params=params5, ax=ax3)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax3.add_artist(ax3.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':'B (G)','yscale':'log','title':r'$max\|B\|$','legend':False}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax3=model0plotter.plotevolveline('face', method='maxbnorm', plot_params=params0, ax=ax3)
ax3=model1plotter.plotevolveline('face', method='maxbnorm', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='maxbnorm', plot_params=params2, ax=ax3)
ax3=model3plotter.plotevolveline('face', method='maxbnorm', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='maxbnorm', plot_params=params4, ax=ax3)
ax3=model5plotter.plotevolveline('face', method='maxbnorm', plot_params=params5, ax=ax3)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax3.add_artist(ax3.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':'J','yscale':'log','title':'Total angular momentum','legend':False}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax3=model0plotter.plotevolveline('face', method='Lz', plot_params=params0, ax=ax3)
ax3=model1plotter.plotevolveline('face', method='Lz', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='Lz', plot_params=params2, ax=ax3)
ax3=model3plotter.plotevolveline('face', method='Lz', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='Lz', plot_params=params4, ax=ax3)
ax3=model5plotter.plotevolveline('face', method='Lz', plot_params=params5, ax=ax3)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax3.add_artist(ax3.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':r'$E_{rot} (erg)$','xlim':(0.01),'yscale':'log','title':r'$E_{rot}$','legend':False}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax3=model0plotter.plotevolveline('face', method='rotenergy', plot_params=params0, ax=ax3)
ax3=model1plotter.plotevolveline('face', method='rotenergy', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='rotenergy', plot_params=params2, ax=ax3)
ax3=model3plotter.plotevolveline('face', method='rotenergy', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='rotenergy', plot_params=params4, ax=ax3)
ax3=model5plotter.plotevolveline('face', method='rotenergy', plot_params=params5, ax=ax3)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax3.add_artist(ax3.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':r'$E_{rot} (erg)$','xlim':(0.01),'yscale':'log','title':r'$E_{rot}$','legend':False}
params1 = {**plot_params, **{'linestyle':'-', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':':', 'color':'orange'}}
# params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
# params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax3=model1plotter.plotevolveline('face', method='rotenergy', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='rotenergy', plot_params=params2, ax=ax3)
# ax3=model3plotter.plotevolveline('face', method='rotenergy', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='rotenergy', plot_params=params4, ax=ax3)
# ax3=model5plotter.plotevolveline('face', method='rotenergy', plot_params=params5, ax=ax3)

# Create custom legend handles
blue_line = mlines.Line2D([], [], color='blue', linestyle='-', label='Fast rot, weak B')
orange_line = mlines.Line2D([], [], color='orange', linestyle='-', label='Fast rot, strong B')
# green_line = mlines.Line2D([], [], color='green', linestyle='-', label='Slow rot, weak B')
red_line = mlines.Line2D([], [], color='red', linestyle='-', label='Fast rot, no B')
# purple_line = mlines.Line2D([], [], color='purple', linestyle='-', label='No rot, strong B')

ax3.add_artist(ax3.legend(handles=[blue_line,orange_line,red_line], loc='lower right'))

fig, ax4 = plt.subplots()
plot_params = {'y': True, 'ylabel':r'$\Delta E_{rot} (erg)$','xlim':(0.01),'yscale':'log','title':r'$E_{rot}$','legend':False}
t = ax3.lines[2].get_xdata()
zeroB = ax3.lines[2].get_ydata()
weakB = ax3.lines[0].get_ydata()
strgB = ax3.lines[1].get_ydata()

ax4.plot(t, zeroB-weakB, label='Fast rot, weak B')
ax4.plot(t, zeroB-strgB, label='Fast rot, strong B')
ax4.legend(loc='lower right')
ax4.grid()

# %%
from matplotlib import lines as mlines
fig, ax2 = plt.subplots()
plot_params = {'ylim':(1e45,2e52), 'ylabel':r'$E_{Kin} (erg)$','xlim':(0.01),'yscale':'log','title':'Kinetic energy','legend':False}

params1 = {**plot_params, **{'linestyle':':', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':':', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':':', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':':', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':':', 'color':'purple'}}
ax2=model1plotter.plotevolveline('face', method='rotenergy', plot_params=params1, ax=ax2)
ax2=model2plotter.plotevolveline('face', method='rotenergy', plot_params=params2, ax=ax2)
ax2=model3plotter.plotevolveline('face', method='rotenergy', plot_params=params3, ax=ax2)
# ax2=model4plotter.plotevolveline('face', method='rotenergy', plot_params=params4, ax=ax2)
# ax2=model5plotter.plotevolveline('face', method='rotenergy', plot_params=params5, ax=ax2)

params6 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params7 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params8 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params9 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params10 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax2=model1plotter.plotevolveline('face', method='radenergy', plot_params=params6, ax=ax2)
ax2=model2plotter.plotevolveline('face', method='radenergy', plot_params=params7, ax=ax2)
ax2=model3plotter.plotevolveline('face', method='radenergy', plot_params=params8, ax=ax2)
# ax2=model4plotter.plotevolveline('face', method='radenergy', plot_params=params9, ax=ax2)
# ax2=model5plotter.plotevolveline('face', method='radenergy', plot_params=params10, ax=ax2)

params11 = {**plot_params, **{'linestyle':'--', 'color':'blue'}}
params12 = {**plot_params, **{'linestyle':'--', 'color':'orange'}}
params13 = {**plot_params, **{'linestyle':'--', 'color':'green'}}
params14 = {**plot_params, **{'linestyle':'--', 'color':'red'}}
params15 = {**plot_params, **{'linestyle':'--', 'color':'purple'}}
ax2=model1plotter.plotevolveline('face', method='angenergy', plot_params=params6, ax=ax2)
ax2=model2plotter.plotevolveline('face', method='angenergy', plot_params=params7, ax=ax2)
ax2=model3plotter.plotevolveline('face', method='angenergy', plot_params=params8, ax=ax2)
# ax2=model4plotter.plotevolveline('face', method='angenergy', plot_params=params9, ax=ax2)
# ax2=model5plotter.plotevolveline('face', method='angenergy', plot_params=params10, ax=ax2)

# Create custom legend handles
phi_line = mlines.Line2D([], [], color='black', linestyle=':', label=r'KE$_{\phi}$')
r_line = mlines.Line2D([], [], color='black', linestyle='-.', label=r'KE$_{r}$')
theta_line = mlines.Line2D([], [], color='black', linestyle='--', label=r'KE$_{\theta}$')
blue_line = mlines.Line2D([], [], color='blue', linestyle='-', label='Fast rot, weak B')
orange_line = mlines.Line2D([], [], color='orange', linestyle='-', label='Fast rot, strong B')
green_line = mlines.Line2D([], [], color='green', linestyle='-', label='Slow rot, weak B')
# red_line = mlines.Line2D([], [], color='red', linestyle='-', label='Fast rot, no B')
# purple_line = mlines.Line2D([], [], color='purple', linestyle='-', label='No rot, strong B')

ax2.add_artist(ax2.legend(handles=[phi_line, r_line, theta_line], loc='upper right'))
ax2.add_artist(ax2.legend(handles=[blue_line,orange_line,green_line], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax3 = plt.subplots()
plot_params = {'y': True, 'ylabel':r'$L_{z} (erg)$','xlim':(0.01),'yscale':'linear','title':'Total angular momentum','legend':False}
params1 = {**plot_params, **{'linestyle':'--', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax3=model1plotter.plotevolveline('face', method='Lz', plot_params=params1, ax=ax3)
ax3=model2plotter.plotevolveline('face', method='Lz', plot_params=params2, ax=ax3)
# ax3=model3plotter.plotevolveline('face', method='Lz', plot_params=params3, ax=ax3)
ax3=model4plotter.plotevolveline('face', method='Lz', plot_params=params4, ax=ax3)
# ax3=model5plotter.plotevolveline('face', method='Lz', plot_params=params5, ax=ax3)

# Create custom legend handles
blue_line = mlines.Line2D([], [], color='blue', linestyle='-', label='Fast rot, weak B')
orange_line = mlines.Line2D([], [], color='orange', linestyle='-', label='Fast rot, strong B')
# green_line = mlines.Line2D([], [], color='green', linestyle='-', label='Slow rot, weak B')
red_line = mlines.Line2D([], [], color='red', linestyle='-', label='Fast rot, no B')
# purple_line = mlines.Line2D([], [], color='purple', linestyle='-', label='No rot, strong B')

ax3.add_artist(ax3.legend(handles=[blue_line,orange_line,red_line], loc='center right'))

# %%
from matplotlib import lines as mlines
fig, ax5 = plt.subplots()
plot_params = {'ylabel':r'$E_{grav}$','xlim':(0.001),'yscale':'linear','title':r'$E_{grav}$','legend':False}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax5=model1plotter.plotevolveline('face', method='gravenergy', plot_params=params1, ax=ax5)
ax5=model2plotter.plotevolveline('face', method='gravenergy', plot_params=params2, ax=ax5)
ax5=model3plotter.plotevolveline('face', method='gravenergy', plot_params=params3, ax=ax5)
ax5=model4plotter.plotevolveline('face', method='gravenergy', plot_params=params4, ax=ax5)
ax5=model5plotter.plotevolveline('face', method='gravenergy', plot_params=params5, ax=ax5)

# Create custom legend handles
blue_line = mlines.Line2D([], [], color='blue', linestyle='-', label='Fast rot, weak B')
orange_line = mlines.Line2D([], [], color='orange', linestyle='-', label='Fast rot, strong B')
green_line = mlines.Line2D([], [], color='green', linestyle='-', label='Slow rot, weak B')
red_line = mlines.Line2D([], [], color='red', linestyle='-', label='Fast rot, no B')
purple_line = mlines.Line2D([], [], color='purple', linestyle='-', label='No rot, strong B')

ax5.add_artist(ax5.legend(handles=[blue_line,orange_line,green_line,red_line,purple_line], loc='lower right'))

# %%
from matplotlib import lines as mlines
fig, ax1 = plt.subplots()
plot_params = {'y': True, 'yscale':'linear', 'xlim':(0.03,0.05), 'ylim':(1.7e14,2.5e14), 'title':r'$\rho_{max}$ against time', 'legend':False}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax1=model0plotter.plotevolveline('rho', location='max', plot_params=params0, ax=ax1)
ax1=model1plotter.plotevolveline('rho', location='max', plot_params=params1, ax=ax1)
ax1=model2plotter.plotevolveline('rho', location='max', plot_params=params2, ax=ax1)
ax1=model3plotter.plotevolveline('rho', location='max', plot_params=params3, ax=ax1)
ax1=model4plotter.plotevolveline('rho', location='max', plot_params=params4, ax=ax1)
ax1=model5plotter.plotevolveline('rho', location='max', plot_params=params5, ax=ax1)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax1.add_artist(ax1.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
fig, ax1 = plt.subplots()
plot_params = {'y': True, 'yscale':'linear','ylabel':r'M ($M_{\bigodot}$)', 'xlim':(0.03), 'ylim':(0,1.3),'title':'PNS mass'}
params0 = {**plot_params, **{'linestyle':'-.', 'color':'yellow', 'label':'2 rad/s'}}
params1 = {**plot_params, **{'linestyle':'-.', 'color':'blue'}}
params2 = {**plot_params, **{'linestyle':'-.', 'color':'orange'}}
params3 = {**plot_params, **{'linestyle':'-.', 'color':'green'}}
params4 = {**plot_params, **{'linestyle':'-.', 'color':'red'}}
params5 = {**plot_params, **{'linestyle':'-.', 'color':'purple'}}
ax1=model0plotter.plotevolveline('rho', method='mass', plot_params=params0, ax=ax1)
ax1=model1plotter.plotevolveline('rho', method='mass', plot_params=params1, ax=ax1)
ax1=model2plotter.plotevolveline('rho', method='mass', plot_params=params2, ax=ax1)
ax1=model3plotter.plotevolveline('rho', method='mass', plot_params=params3, ax=ax1)
ax1=model4plotter.plotevolveline('rho', method='mass', plot_params=params4, ax=ax1)
ax1=model5plotter.plotevolveline('rho', method='mass', plot_params=params5, ax=ax1)

# Create custom legend handles
line0 = mlines.Line2D([], [], color='yellow', linestyle='-', label='2 rad/s')
line1 = mlines.Line2D([], [], color='blue'  , linestyle='-', label='4 rad/s')
line2 = mlines.Line2D([], [], color='orange', linestyle='-', label='6 rad/s')
line3 = mlines.Line2D([], [], color='green' , linestyle='-', label='8 rad/s')
line4 = mlines.Line2D([], [], color='red'   , linestyle='-', label='10 rad/s')
line5 = mlines.Line2D([], [], color='purple', linestyle='-', label='10.8 rad/s')

ax1.add_artist(ax1.legend(handles=[line0,line1,line2,line3,line4,line5], loc='lower right'))

# %%
fig, ax5 = plt.subplots()
specialplotter = plotter.HDF5Plotter(file_pattern=f"{models[1]}/rkiter-*.hdf5",exclude_last_n_files=1)
params2 = {'yscale':'linear','xscale':'log','xlim':(1,200),'ylabel':r'$U_{eff}$ (s$^{-1}$)','title':'Fast rot, strong B'}
ax5 = specialplotter.plotevolveprofile('face',custom='effU', plot_params=params2, ax=ax5, close_up=True)

# %%
fig, ax4 = plt.subplots()
params2 = {'yscale':'log','xscale':'log','xlim':(1,1e3),'ylim':(1e1,1e4),'ylabel':r'$\Omega$ (s$^{-1}$)','title':'Fast rot, strong B'}
ax4 = model0plotter.plotevolveprofile('omega', bounce=True, plot_params=params2, ax=ax4)
r = ax4.lines[0].get_xdata()
mass2code = model2plotter.rhocgs2code*model2plotter.lencgs2code**3
mass = 1.27*1.989e33
G = 6.67430e-8
kep = (G*mass/(r*1e5)**3)**0.5
ax4.plot(r,kep,linestyle='--',color='black',label='Keplerian')

# %%
fig, ax5 = plt.subplots()
specialplotter = plotter.HDF5Plotter(file_pattern=f"{models[1]}/rkiter-*.hdf5",exclude_last_n_files=1)
params2 = {'yscale':'log','xscale':'log','xlim':(1,200),'ylabel':r'$j=rv_{\phi}$','title':'Fast rot, strong B'}
ax5 = specialplotter.plotevolveprofile('face',custom='j', plot_params=params2, ax=ax5)
r = ax5.lines[0].get_xdata()
mass2code = model2plotter.rhocgs2code*model2plotter.lencgs2code**3
mass = 1.27*1.989e33
G = 6.67430e-8
kep = (r)**2*(G*mass/(r*1e5)**3)**0.5
ax5.plot(r,kep,linestyle='--',color='black',label='Keplerian')

# %%
fig, ax5 = plt.subplots()
specialplotter = plotter.HDF5Plotter(file_pattern=f"{models[5]}/rkiter-*.hdf5",exclude_last_n_files=1)
params2 = {'yscale':'log','xscale':'log','xlim':(1,200),'ylabel':r'$j=rv_{\phi}$','title':'Fast rot, No B'}
ax5 = specialplotter.plotevolveprofile('face',custom='j', plot_params=params2, ax=ax5)
r = ax5.lines[0].get_xdata()
mass2code = model5plotter.rhocgs2code*model5plotter.lencgs2code**3
mass = 1.27*1.989e33
G = 6.67430e-8
kep = (r)**2*(G*mass/(r*1e5)**3)**0.5
ax5.plot(r,kep,linestyle='--',color='black',label='Keplerian')

# %%
fig, ax5 = plt.subplots()
specialplotter = plotter.HDF5Plotter(file_pattern=f"{models[1]}/rkiter-*.hdf5",exclude_last_n_files=1)
params2 = {'yscale':'log','xscale':'log','ylabel':r'$vphi$ (s$^{-1}$)','title':'Fast rot, strong B'}
ax5 = specialplotter.plotevolveprofile('vz', plot_params=params2, ax=ax5)
